# %%
import pandas as pd
from IPython.display import Image
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 📺 Breaking Bad Viewership Analysis
#
# **_Breaking Bad_** is an American television series created by **Vince Gilligan**. It premiered on **AMC** in 2008 and ran for **five seasons**, concluding in 2013. The show follows **Walter White**, a chemistry teacher turned meth producer.
#
# Below is a brief analysis of its viewership trend.

# %%
Image("breaking_bad_logo.png")

# %%
data = {
    "Season": [
        "The Complete First Season",
        "The Complete Second Season",
        "The Complete Third Season",
        "The Complete Fourth Season",
        "The Fifth Season",
        "The Final Season",
        "The Complete Series"
    ],
    "Release Date": [
        "March 3, 2009",
        "March 9, 2010",
        "June 7, 2011",
        "June 5, 2012",
        "June 4, 2013",
        "November 26, 2013",
        "November 26, 2013"
    ],
    "Episodes": [7, 13, 13, 13, 8, 8, 62],
    "Discs": [3, 4, 4, 4, 3, 3, 21]
}

df = pd.DataFrame(data)
df
# Out:
#                        Season       Release Date  Episodes  Discs
# 0   The Complete First Season      March 3, 2009         7      3
# 1  The Complete Second Season      March 9, 2010        13      4
# 2   The Complete Third Season       June 7, 2011        13      4
# 3  The Complete Fourth Season       June 5, 2012        13      4
# 4            The Fifth Season       June 4, 2013         8      3
# 5            The Final Season  November 26, 2013         8      3
# 6         The Complete Series  November 26, 2013        62     21
